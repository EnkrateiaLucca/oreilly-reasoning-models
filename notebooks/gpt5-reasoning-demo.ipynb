# %% [markdown]
# # GPT-5 Reasoning Models: A Practical Guide
#
# This notebook demonstrates OpenAI's GPT-5 reasoning capabilities using the **Responses API**.
#
# ## What Are Reasoning Models?
#
# Reasoning models emit **hidden reasoning tokens** before generating their final answer. This allows them to:
# - Break down complex problems into steps
# - Explore multiple approaches before committing to an answer
# - Verify their work and catch mistakes
# - Handle multi-step tasks more reliably
#
# Think of it like showing your work in math class - the model "thinks through" the problem before answering.

# %% [markdown]
# ## Setup
#
# First, let's set up our OpenAI client with the Responses API.

# %%
import os
import getpass
from openai import OpenAI
from dotenv import load_dotenv

# Load environment variables from .env file (if it exists)
load_dotenv()

# Set API key
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

client = OpenAI()
print("✓ OpenAI client initialized")
# Out:
# ✓ OpenAI client initialized

# %% [markdown]
# ## Reasoning Effort Levels
#
# GPT-5 supports four reasoning effort levels:
#
# | Level | Use When | Speed | Cost | Quality |
# |-------|----------|-------|------|----------|
# | **minimal** | Simple classification, extraction, formatting | Fastest | Lowest | Good |
# | **low** | Straightforward tasks with some reasoning | Fast | Low | Better |
# | **medium** | Balanced default for most workflows | Moderate | Moderate | Great |
# | **high** | Complex multi-step tasks, critical accuracy | Slower | Higher | Best |
#
# **Key Insight**: Higher effort = more reasoning tokens = better accuracy but higher latency/cost

# %% [markdown]
# ## Example 1: Minimal Reasoning - Quick Classification
#
# Perfect for: sentiment analysis, simple categorization, extraction tasks

# %%
# Simple sentiment classification with minimal reasoning
response = client.responses.create(
    model="gpt-5",
    reasoning={"effort": "minimal"},
    input=[
        {
            "role": "developer",
            "content": "Classify the sentiment as: positive, neutral, or negative. Return only one word."
        },
        {
            "role": "user",
            "content": "The new update completely broke my workflow. Very disappointed."
        }
    ]
)

print(f"Sentiment: {response.output_text}")
print(f"Total tokens: {response.usage.total_tokens}")
# Out:
# Sentiment: negative
# Total tokens: 58

# %% [markdown]
# ## Example 2: Medium Reasoning - Code Generation
#
# Perfect for: standard coding tasks, data transformations, moderate complexity problems

# %%
# Generate a practical Python function with medium reasoning
prompt = """
Write a Python function that validates an email address.
Requirements:
- Check for @ symbol
- Verify domain has at least one dot
- Ensure no spaces
- Return True/False

Include a docstring and 2-3 test cases.
"""

response = client.responses.create(
    model="gpt-5",
    reasoning={"effort": "medium"},
    input=[{"role": "user", "content": prompt}]
)

print(response.output_text)
print(f"\n{'='*60}")
print(f"Reasoning tokens: {response.usage.output_tokens_details.reasoning_tokens}")
print(f"Output tokens: {response.usage.output_tokens}")
# Out:
# ```python
# def validate_email(email: str) -> bool:
#     """
#     Validate an email address using simple rules:
#     - Contains exactly one '@' symbol.
#     - Domain part (after '@') has at least one '.' (not at the start or end).
#     - Contains no whitespace characters (spaces, tabs, newlines).
#     - Local and domain parts are non-empty.
#
#     Returns:
#         bool: True if the email passes the checks, otherwise False.
#     """
#     if not isinstance(email, str):
#         return False
#
#     # No whitespace
#     if any(ch.isspace() for ch in email):
#         return False
#
#     # Exactly one '@'
#     if email.count("@") != 1:
#         return False
#
#     local, domain = email.split("@", 1)
#     if not local or not domain:
#         return False
#
#     # Domain must contain a dot not at start or end and not in consecutive positions
#     if "." not in domain or domain.startswith(".") or domain.endswith("."):
#         return False
#     if any(part == "" for part in domain.split(".")):
#         return False
#
#     return True
#
#
# # Test cases
# tests = [
#     ("user@example.com", True),
#     ("user@example", False),            # domain lacks a dot
#     ("user @example.com", False),       # contains a space
# ]
#
# for addr, expected in tests:
#     result = validate_email(addr)
#     print(f"{addr!r} -> {result} (expected {expected})")
# ```
#
# ============================================================
# Reasoning tokens: 1024
# Output tokens: 1348

# %% [markdown]
# ## Example 3: High Reasoning - Complex Problem Solving
#
# Perfect for: algorithm design, multi-step logic, edge case handling, critical accuracy needs

# %%
# Complex algorithmic problem with high reasoning
problem = """
Design an algorithm to find the longest palindromic substring in a string.

Requirements:
- Handle edge cases (empty string, single character, no palindromes)
- Optimize for time complexity
- Provide the implementation in Python
- Explain the approach and time/space complexity
"""

response = client.responses.create(
    model="gpt-5",
    reasoning={"effort": "high"},
    input=[{"role": "user", "content": problem}]
)

print(response.output_text)
print(f"\n{'='*60}")
print(f"Reasoning tokens: {response.usage.output_tokens_details.reasoning_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
# Out:
# Approach (optimized): Manacher’s algorithm
# - Idea: Treat every position as a center and expand palindromes, but reuse information from previously computed centers to achieve linear time.
# - Trick: Insert separators (e.g., '#') between characters so that both odd- and even-length palindromes are handled uniformly. Use sentinels to avoid bounds checks.
# - Maintain:
#   - center: the index of the current rightmost palindrome’s center in the transformed string
#   - right: the right boundary of that palindrome
#   - p[i]: radius (half-length) of the palindrome centered at i in the transformed string
# - For each i, use the mirror position mir = 2*center - i to initialize p[i], then expand further if possible. Update center/right when you extend beyond right.
#
# Edge cases
# - Empty string -> return ""
# - Single character -> return that character
# - No palindrome longer than 1 -> returns a single-character substring (every single char is a palindrome)
#
# Python implementation
#
# ```python
# def longest_palindromic_substring(s: str) -> str:
#     """
#     Returns the longest palindromic substring of s using Manacher's algorithm.
#     Time: O(n), Space: O(n)
#     """
#     if not s:
#         return ""
#
#     # Transform: "^#a#b#c#$" (sentinels avoid bounds checks)
#     t = "^#" + "#".join(s) + "#$"
#     n = len(t)
#     p = [0] * n  # p[i] = radius of palindrome around i in transformed string
#     center = right = 0
#
#     for i in range(1, n - 1):
#         mirror = 2 * center - i
#         if i < right:
#             p[i] = min(right - i, p[mirror])
#
#         # Expand around i
#         while t[i + p[i] + 1] == t[i - p[i] - 1]:
#             p[i] += 1
#
#         # Update center and right boundary if expanded beyond current right
#         if i + p[i] > right:
#             center = i
#             right = i + p[i]
#
#     # Find the maximum radius and its center
#     max_len = 0
#     center_index = 0
#     for i in range(1, n - 1):
#         if p[i] > max_len:
#             max_len = p[i]
#             center_index = i
#
#     # Map back to original string indices
#     start = (center_index - max_len) // 2
#     return s[start:start + max_len]
# ```
#
# Complexity
# - Time: O(n), because each position is processed at most a constant number of times thanks to the reuse of mirror information.
# - Space: O(n) for the transformed string and the p array.
#
# Notes
# - A simpler alternative is “expand around center” (try each index as the center and expand left/right), which is O(n^2) time and O(1) extra space; Manacher’s is preferred when optimizing for time.
#
# ============================================================
# Reasoning tokens: 3328
# Total tokens: 4095

# %% [markdown]
# ## Example 4: Verbosity Control
#
# GPT-5 introduces a **verbosity** parameter to control output length (separate from reasoning depth).

# %%
question = "What is dependency injection and why is it useful?"

# Try different verbosity levels
for verbosity in ["low", "medium", "high"]:
    response = client.responses.create(
        model="gpt-5",
        reasoning={"effort": "medium"},
        text={"verbosity": verbosity},
        input=[{"role": "user", "content": question}]
    )
    
    print(f"\n{'='*60}")
    print(f"VERBOSITY: {verbosity.upper()}")
    print(f"{'='*60}")
    print(response.output_text)
    print(f"\nOutput tokens: {response.usage.output_tokens}")
# Out:
# ============================================================
# VERBOSITY: LOW
# ============================================================
# Dependency injection (DI) is a technique where an object’s dependencies are provided from the outside rather than the object creating them itself (inversion of control). Instead of new-ing its collaborators, a class receives them (usually via its constructor).
#
# Why it’s useful:
# - Decouples code: depend on interfaces, swap implementations easily.
# - Improves testability: inject mocks/fakes for unit tests.
# - Centralizes wiring/configuration: different environments, lifetimes, scopes.
# - Enhances maintainability: explicit dependencies, simpler classes (SRP).
# - Enables modularity and reuse.
#
# Common forms:
# - Constructor injection (preferred)
# - Setter/property injection
# - Method/parameter injection
#
# With or without a container:
# - You can do DI manually, or use a DI container (e.g., Spring, .NET, Angular) to resolve graphs and manage lifetimes.
#
# Caveats:
# - Don’t hide dependencies via a Service Locator (anti-pattern).
# - Avoid overuse/over-abstraction; keep a clear composition root and explicit dependencies.
#
# Output tokens: 839
#
# ============================================================
# VERBOSITY: MEDIUM
# ============================================================
# Dependency injection (DI) is a way to give an object the collaborators it needs (its dependencies) from the outside, rather than having the object create them itself. This inverts control: objects declare what they need; something else builds the graph and supplies them.
#
# Simple example
# Without DI:
# class BillingService {
#   private PaymentGateway gateway = new StripeGateway(); // hard‑coded
# }
#
# With DI:
# interface PaymentGateway { charge(amount) }
# class BillingService {
#   private final PaymentGateway gateway;
#   BillingService(PaymentGateway gateway) { this.gateway = gateway; }
# }
# // At composition root:
# new BillingService(new StripeGateway());
#
# For tests:
# new BillingService(new FakeGateway());
#
# Why it’s useful
# - Decoupling and flexibility: Code depends on interfaces/abstractions, not concrete classes. You can swap implementations (e.g., StripeGateway to PayPalGateway) without changing consumers.
# - Testability: You can pass fakes/mocks/stubs, enabling fast, isolated unit tests.
# - Maintainability: Clear, explicit dependencies; fewer hidden new calls and singletons.
# - Reuse and composability: Components become more reusable across apps.
# - Lifecycle management (when using a container): Central control over singletons, scoped, and transient services.
#
# Common ways to inject
# - Constructor injection (preferred): Dependencies are required and immutable.
# - Setter/property injection: Optional or late-bound dependencies.
# - Method injection: Passed just for a single call.
#
# Using a DI container (optional)
# - You register mappings (Interface -> Implementation).
# - The container resolves and injects dependencies, often auto-wiring large object graphs.
# - Manages lifetimes: singleton, scoped (per request), transient.
#
# Service Locator vs DI
# - DI: Dependencies are provided to a class (explicit).
# - Service Locator: The class asks a global locator for what it needs (implicit, tends to hide dependencies). Generally discouraged compared to DI.
#
# When not to use
# - Very small scripts or simple modules where manual wiring is clearer.
# - Performance-critical hot paths where container overhead matters (manual wiring may be better).
#
# Gotchas and tips
# - Prefer constructor injection; avoid too many constructor params by refactoring to smaller objects.
# - Keep a single composition root where wiring happens.
# - Beware circular dependencies; they signal design issues.
# - Don’t inject containers into services; inject the specific dependencies instead.
#
# Popular frameworks
# - Java: Spring, Guice, Dagger
# - .NET: Built-in DI container
# - JavaScript/TypeScript: Angular, NestJS, Inversify
# - Kotlin/Android: Hilt/Dagger, Koin
#
# Output tokens: 1241
#
# ============================================================
# VERBOSITY: HIGH
# ============================================================
# Dependency injection (DI) is a way to give an object the things it depends on (its collaborators) from the outside instead of the object creating them itself. In other words, you supply dependencies rather than having classes construct or look them up. This inverts control: the class no longer controls how its dependencies are obtained.
#
# Simple before-and-after example
#
# Without DI:
# - UserService needs an EmailSender, so it creates one directly.
# - This hard‑codes the dependency and makes testing harder.
#
# Example:
# class EmailSender {
#   void send(String to, String body) { /* ... */ }
# }
#
# class UserService {
#   private final EmailSender emailSender = new EmailSender();
#   void register(User user) {
#     // ...
#     emailSender.send(user.email(), "Welcome!");
#   }
# }
#
# With DI:
# - UserService receives an EmailSender from the outside (constructor parameter).
# - You can supply any implementation (real, fake, mock) without changing UserService.
#
# Example:
# interface Mailer { void send(String to, String body); }
#
# class SmtpMailer implements Mailer { /* ... */ }
#
# class UserService {
#   private final Mailer mailer;
#   UserService(Mailer mailer) { this.mailer = mailer; }
#   void register(User user) { mailer.send(user.email(), "Welcome!"); }
# }
#
# // Wiring:
# UserService svc = new UserService(new SmtpMailer());
#
# // In tests:
# UserService svc = new UserService(new FakeMailer());
#
# Why it’s useful
#
# - Looser coupling and flexibility: Classes depend on abstractions (interfaces) rather than concrete implementations, making it easy to swap implementations (e.g., different databases, mailers, feature flags, configuration).
# - Testability: You can pass fakes/mocks/stubs in tests without heavy setup, enabling fast unit tests.
# - Separation of concerns: Classes focus on behavior; construction and wiring happen elsewhere (often called the composition root).
# - Maintainability and readability: Dependencies are explicit in constructors, making requirements clear.
# - Configuration and lifecycle management: A DI container can centralize creation, configuration, scoping (singleton, per request, transient), and disposal of components.
# - Aligns with SOLID principles:
#   - Dependency Inversion Principle (depend on abstractions).
#   - Single Responsibility (objects don’t manage their own wiring).
#
# Common ways to inject dependencies
#
# - Constructor injection (preferred): Require dependencies in the constructor. Makes required dependencies explicit and supports immutability.
# - Setter injection: Provide optional or replaceable dependencies via setters.
# - Method parameter injection: Pass dependencies directly to specific methods.
# - Field injection: Framework sets fields directly; convenient but harder to test and hides required dependencies.
# - Interface injection (rare): The dependency is injected via an interface method the class implements.
#
# DI vs IoC containers
#
# - DI is the pattern of supplying dependencies from the outside.
# - An IoC/DI container is a tool that automates wiring: it knows how to build objects, resolve their dependencies, manage lifetimes, and often configuration.
# - You can do DI manually (newing things up in a composition root), or use a container. Containers help at scale but add indirection.
#
# Scopes and lifecycles (with containers)
#
# - Singleton: One instance for the app (e.g., configuration, logger).
# - Scoped: One per logical scope (e.g., per web request).
# - Transient: New instance each time it’s requested.
# - Containers can also do lazy instantiation, interception (e.g., logging, metrics), and automatic disposal.
#
# When DI might be overkill or misused
#
# - Very small scripts or simple, stable modules: passing one or two parameters manually is fine.
# - Over-abstracting: Creating interfaces for everything can introduce unnecessary complexity.
# - Service locator anti-pattern: Hiding dependencies behind a global lookup (ServiceLocator.get()) makes code harder to test and reason about. Prefer explicit injection.
# - Excessive magic: Heavy use of reflection/annotations can hinder debuggability; prefer explicit wiring where possible.
#
# Ecosystem examples
#
# - Java: Spring, Guice, Dagger, Micronaut. Spring uses annotations and a container to wire beans, manage scopes, and lifecycle.
# - .NET: Built-in DI container (IServiceCollection, IServiceProvider) with scoped/singleton/transient lifetimes.
# - JavaScript/TypeScript: Angular and NestJS have built-in DI; in Node, lightweight options or manual composition are common.
# - Python: FastAPI’s Depends (request-scoped injections), dependency-injector library, or manual wiring.
# - Other: Many frameworks provide DI to manage controllers, services, repositories, etc.
#
# Practical tips
#
# - Prefer constructor injection for required dependencies; keep constructors small.
# - Define interfaces only where you truly need substitutability (e.g., external systems).
# - Create a composition root (application startup) that wires the graph in one place.
# - Keep object graphs shallow when possible; refactor if a class needs many dependencies (it might be doing too much).
# - In tests, inject fakes/mocks directly; with containers, you can override registrations in test modules.
#
# In short: Dependency injection makes code easier to test, change, and reason about by externalizing how dependencies are provided and managed, often with help from a container to automate wiring and lifecycle at scale.
#
# Output tokens: 1684

# %% [markdown]
# ## Example 5: Comparing Reasoning Efforts
#
# Let's see how different reasoning levels handle the same moderately complex task.

# %%
task = """
You have a list of meeting times in 24-hour format as strings: 
["09:00-10:30", "10:00-11:00", "14:00-15:30", "15:00-16:00"]

Write a Python function that finds all overlapping meetings.
Return a list of tuples showing which meetings overlap.
"""

efforts = ["minimal", "medium", "high"]
results = {}

for effort in efforts:
    response = client.responses.create(
        model="gpt-5",
        reasoning={"effort": effort},
        input=[{"role": "user", "content": task}]
    )
    
    results[effort] = {
        "output": response.output_text,
        "reasoning_tokens": response.usage.output_tokens_details.reasoning_tokens,
        "output_tokens": response.usage.output_tokens,
        "total_tokens": response.usage.total_tokens
    }

# Display comparison
for effort in efforts:
    print(f"\n{'='*70}")
    print(f"REASONING EFFORT: {effort.upper()}")
    print(f"{'='*70}")
    print(results[effort]["output"])
    print(f"\n📊 Token Usage:")
    print(f"   Reasoning: {results[effort]['reasoning_tokens']}")
    print(f"   Output: {results[effort]['output_tokens']}")
    print(f"   Total: {results[effort]['total_tokens']}")
# Out:
# ======================================================================
# REASONING EFFORT: MINIMAL
# ======================================================================
# Here's a simple Python function that parses the time ranges, converts them to minutes, and finds all overlapping pairs:
#
# ```python
# def find_overlapping_meetings(meetings):
#     # Convert "HH:MM-HH:MM" to (start_minutes, end_minutes)
#     def to_minutes(t):
#         h, m = map(int, t.split(':'))
#         return h * 60 + m
#
#     intervals = []
#     for s in meetings:
#         start_str, end_str = s.split('-')
#         intervals.append((to_minutes(start_str), to_minutes(end_str), s))
#
#     overlaps = []
#     n = len(intervals)
#     for i in range(n):
#         for j in range(i + 1, n):
#             s1, e1, m1 = intervals[i]
#             s2, e2, m2 = intervals[j]
#             # Overlap if start < other end and other start < end
#             if s1 < e2 and s2 < e1:
#                 overlaps.append((m1, m2))
#     return overlaps
#
# # Example usage:
# meetings = ["09:00-10:30", "10:00-11:00", "14:00-15:30", "15:00-16:00"]
# print(find_overlapping_meetings(meetings))
# # Output:
# # [('09:00-10:30', '10:00-11:00'), ('14:00-15:30', '15:00-16:00')]
# ```
#
# 📊 Token Usage:
#    Reasoning: 0
#    Output: 332
#    Total: 411
#
# ======================================================================
# REASONING EFFORT: MEDIUM
# ======================================================================
# def find_overlapping_meetings(meetings):
#     def time_to_minutes(t):
#         h, m = map(int, t.split(":"))
#         return h * 60 + m
#
#     def parse_range(r):
#         start_str, end_str = r.split("-")
#         return time_to_minutes(start_str), time_to_minutes(end_str)
#
#     def overlaps(a, b):
#         a_start, a_end = parse_range(a)
#         b_start, b_end = parse_range(b)
#         # Overlap if intervals intersect with positive length
#         return a_start < b_end and b_start < a_end
#
#     result = []
#     n = len(meetings)
#     for i in range(n):
#         for j in range(i + 1, n):
#             if overlaps(meetings[i], meetings[j]):
#                 result.append((meetings[i], meetings[j]))
#     return result
#
# # Example
# meetings = ["09:00-10:30", "10:00-11:00", "14:00-15:30", "15:00-16:00"]
# print(find_overlapping_meetings(meetings))
# # Output: [('09:00-10:30', '10:00-11:00'), ('14:00-15:30', '15:00-16:00')]
#
# 📊 Token Usage:
#    Reasoning: 1408
#    Output: 1746
#    Total: 1825
#
# ======================================================================
# REASONING EFFORT: HIGH
# ======================================================================
# def find_overlaps(meetings):
#     # Touching at endpoints (e.g., 10:00-11:00 and 11:00-12:00) is not considered overlapping.
#     def to_minutes(t):
#         h, m = map(int, t.split(':'))
#         return h * 60 + m
#
#     parsed = []
#     for slot in meetings:
#         start_str, end_str = slot.split('-')
#         parsed.append((to_minutes(start_str), to_minutes(end_str), slot))
#
#     overlaps = []
#     n = len(parsed)
#     for i in range(n):
#         for j in range(i + 1, n):
#             s1, e1, t1 = parsed[i]
#             s2, e2, t2 = parsed[j]
#             if s1 < e2 and s2 < e1:
#                 overlaps.append((t1, t2))
#     return overlaps
#
# # Example usage
# meetings = ["09:00-10:30", "10:00-11:00", "14:00-15:30", "15:00-16:00"]
# print(find_overlaps(meetings))
# # Output: [('09:00-10:30', '10:00-11:00'), ('14:00-15:30', '15:00-16:00')]
#
# 📊 Token Usage:
#    Reasoning: 1920
#    Output: 2263
#    Total: 2342

# %% [markdown]
# ## Best Practices for GPT-5 Reasoning Models
#
# ### 1. **Don't Ask for Chain-of-Thought**
# ❌ Bad: "Think step-by-step and show your reasoning"
# ✓ Good: Just state the task clearly
#
# *Reasoning models already think internally - asking them to plan more can degrade performance.*
#
# ### 2. **Choose the Right Effort Level**
# - **minimal**: Classification, extraction, simple formatting
# - **medium**: Default for most tasks (best price/performance)
# - **high**: Critical accuracy, complex multi-step problems
#
# ### 3. **Be Clear and Direct**
# - Use explicit instructions
# - Avoid contradictory directives
# - Define clear success criteria
#
# ### 4. **Use Developer Messages**
# Set context and tone with `{"role": "developer"}` messages:
# ```python
# {
#     "role": "developer",
#     "content": "You are a Python expert. Provide production-ready code with error handling."
# }
# ```
#
# ### 5. **Control Verbosity Separately**
# Use `text={"verbosity": "low"}` for concise outputs when you don't need detailed explanations.
#
# ### 6. **Leverage the Responses API**
# Use `responses.create()` instead of `chat.completions.create()` for better reasoning persistence across tool calls.

# %% [markdown]
# ## When to Use Reasoning Models?
#
# ### ✅ Great Use Cases
# - Complex code generation and debugging
# - Multi-step problem solving
# - Data analysis with multiple considerations
# - Document comparison and legal review
# - Algorithm design
# - Tasks requiring verification and self-correction
#
# ### ⚠️ Probably Overkill
# - Simple text generation
# - Basic Q&A
# - Creative writing
# - Translation
# - Summarization of straightforward content
#
# *For these simpler tasks, consider GPT-4.1 or use `reasoning={"effort": "minimal"}` to reduce latency and cost.*

# %% [markdown]
# ## Example 6: Practical Application - Bug Detection
#
# Let's use medium reasoning to analyze code for potential bugs.

# %%
buggy_code = '''
def calculate_average(numbers):
    total = 0
    for num in numbers:
        total += num
    return total / len(numbers)

def process_user_data(data):
    result = {}
    for item in data:
        result[item['id']] = item['name'].upper()
    return result
'''

prompt = f"""
Review this Python code for potential bugs, edge cases, and issues.
For each issue found:
1. Describe the problem
2. Show what input would cause it to fail
3. Provide a fix

Code:
```python
{buggy_code}
```
"""

response = client.responses.create(
    model="gpt-5",
    reasoning={"effort": "medium"},
    input=[{"role": "user", "content": prompt}]
)

print(response.output_text)
# Out:
# Here are the issues I see, along with failing inputs and fixes.
#
# Function: calculate_average
#
# 1) Empty input → division by zero
# - Problem: len(numbers) == 0 triggers ZeroDivisionError.
# - Failing input: []
# - Fix: Detect empty and raise a clear error (or return a sentinel). Also avoid calling len on iterables without length.
#
# 2) Iterable without len (e.g., generator) → TypeError at len(numbers)
# - Problem: Generators/iterators don’t implement len().
# - Failing input: (n for n in [1, 2, 3])
# - Fix: Iterate once, tracking count while summing.
#
# 3) Non-numeric items → TypeError during addition or division
# - Problem: Mixing in non-numeric values breaks addition or division.
# - Failing input: [1, "2", 3]
# - Fix: Validate elements are numbers.Number; raise a clear error otherwise.
#
# 4) None or non-iterable input → TypeError with unclear message
# - Problem: for num in numbers raises TypeError but message may be unclear.
# - Failing input: None
# - Fix: Validate input is iterable and not None; raise a clear error.
#
# Fixed calculate_average:
# ```python
# from numbers import Number
#
# def calculate_average(numbers):
#     if numbers is None:
#         raise TypeError("numbers must be an iterable of numeric values")
#     total = 0
#     count = 0
#     for num in numbers:
#         if not isinstance(num, Number):
#             raise TypeError(f"All elements must be numeric, got {type(num).__name__}")
#         total += num
#         count += 1
#     if count == 0:
#         raise ValueError("numbers must not be empty")
#     return total / count
# ```
#
# Function: process_user_data
#
# 1) Missing 'id' or 'name' → KeyError
# - Problem: item['id'] or item['name'] fails if key missing.
# - Failing input: [{'name': 'Alice'}] or [{'id': 1}]
# - Fix: Check required keys and raise a clear error.
#
# 2) name not a string → AttributeError on .upper()
# - Problem: None or non-string has no upper().
# - Failing input: [{'id': 1, 'name': None}]
# - Fix: Validate type; either coerce to str or require str. Here: require str.
#
# 3) id not hashable → TypeError as dict key
# - Problem: Unhashable keys (e.g., list) cannot be used as dict keys.
# - Failing input: [{'id': ['x'], 'name': 'Bob'}]
# - Fix: Validate hashability (e.g., via hash()).
#
# 4) Duplicate ids silently overwrite
# - Problem: Later items overwrite earlier ones with same id.
# - Failing input: [{'id': 1, 'name': 'Alice'}, {'id': 1, 'name': 'Bob'}]
# - Fix: Decide on behavior. Here: reject duplicates with a clear error. Alternatively, collect duplicates in a list.
#
# 5) Non-dict items or non-iterable data → TypeError
# - Problem: Iterating over non-dicts or non-iterables fails or behaves unexpectedly.
# - Failing input: [1, 2] or None
# - Fix: Validate that each item is a dict and that data is iterable.
#
# Fixed process_user_data (reject duplicates, validate inputs):
# ```python
# def process_user_data(data):
#     if data is None:
#         raise TypeError("data must be an iterable of dicts with 'id' and 'name'")
#     result = {}
#     for idx, item in enumerate(data):
#         if not isinstance(item, dict):
#             raise TypeError(f"Item at index {idx} must be a dict, got {type(item).__name__}")
#         if 'id' not in item or 'name' not in item:
#             raise ValueError(f"Item at index {idx} must contain 'id' and 'name'")
#         key = item['id']
#         try:
#             hash(key)
#         except TypeError:
#             raise TypeError(f"'id' at index {idx} must be hashable, got {type(key).__name__}")
#         name = item['name']
#         if not isinstance(name, str):
#             raise TypeError(f"'name' at index {idx} must be a string, got {type(name).__name__}")
#         if key in result:
#             raise ValueError(f"Duplicate id detected: {key} (at index {idx})")
#         result[key] = name.upper()
#     return result
# ```
#
# Alternative for duplicates (if you prefer keeping all entries):
# - Change the result to map id -> list of uppercased names.
# - Initialize result.setdefault(key, []).append(name.upper()) instead of raising.

# %% [markdown]
# ## Key Takeaways
#
# 1. **Reasoning models think before answering** - hidden reasoning tokens enable better problem-solving
#
# 2. **Start with medium effort** - it's the best balance for most tasks
#
# 3. **Use minimal for speed** - when you need fast responses for simple tasks
#
# 4. **Use high for accuracy** - when correctness is critical and you can afford the latency
#
# 5. **Keep prompts clear and direct** - don't ask the model to "think step-by-step"
#
# 6. **Control output length with verbosity** - separate from reasoning depth
#
# 7. **Use the Responses API** - it's designed specifically for reasoning models

# %% [markdown]
# ## Resources
#
# - [OpenAI GPT-5 Documentation](https://platform.openai.com/docs/models#gpt-5)
# - [OpenAI Cookbook - GPT-5 Prompting Guide](https://cookbook.openai.com/examples/gpt-5/gpt-5_prompting_guide)
# - [Responses API Documentation](https://platform.openai.com/docs/api-reference/responses)
