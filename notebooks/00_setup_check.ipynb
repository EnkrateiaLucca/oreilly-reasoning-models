# %% [markdown]
# # 00 — Setup check
#
# Run every cell. If they all succeed, you're ready for the rest of the course.

# %%
import sys, platform
print('Python:', sys.version.split()[0])
print('Platform:', platform.platform())

# %%
import torch
print('torch:', torch.__version__)
print('cuda:', torch.cuda.is_available(), '| mps:', torch.backends.mps.is_available())

# %%
import transformers, datasets, trl
print('transformers:', transformers.__version__)
print('datasets:', datasets.__version__)
print('trl:', trl.__version__)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
tok = AutoTokenizer.from_pretrained('gpt2')
model = AutoModelForCausalLM.from_pretrained('gpt2')
print('OK — gpt2 loaded:', sum(p.numel() for p in model.parameters())/1e6, 'M params')

# %% [markdown]
# ✅ If this cell printed without errors, you're ready. Open `01_chain_of_thought_intuition.ipynb`.
